# %%
import sys
import os
import logging

sys.path.insert( 0, "." )
from sql_query_conf_matrices_objects import ConfMatrixClient

# %%
url = "https://desc-tom.lbl.gov"
# url = "https://desc-tom-rknop-dev.lbl.gov"

# Somehow you need to set the "username" and "password" variables.
# Do NOT hardcode the password into any code that will be world
# readable.  You can use the python input statement, or, as I do
# here, read the password from a file that is only readable by
# you.  (This isn't perfect, but it's better than having the
# password sit around in a world readable file.)
username = "rknop"
with open( os.path.join( os.getenv("HOME"), "secrets", "tom_rknop_passwd" ) ) as ifp:
    password = ifp.readline().strip()

# %%
logging.basicConfig(level=logging.INFO, format='[%(asctime)s - %(levelname)s] %(message)s', stream=sys.stderr )

# %%
client = ConfMatrixClient.from_credentials( username, password )
logging.info( f'ConfMatrixClient found {len(client.classifiers)} classifiers.' )
client.get_classifications( definition='last_best', classifier_id=None )
# Out:
# Making ConfMatrixClient.[2022-10-20 08:45:10,331 - INFO] [{'brokerName': 'ALeRCE',
#   'brokerVersion': '1.0.0',
#   'classifierId': 41,
#   'classifierName': 'messi',
#   'classifierParams': '1.0.0',
#   'modified': '2022-09-28T20:39:16.875Z'},
#  {'brokerName': 'ALeRCE',
#   'brokerVersion': '2.0.1',
#   'classifierId': 42,
#   'classifierName': 'toretto',
#   'classifierParams': '2.0.1',
#   'modified': '2022-09-28T22:09:28.870Z'},
#  {'brokerName': 'ALeRCE',
#   'brokerVersion': '3.1.0',
#   'classifierId': 40,
#   'classifierName': 'balto',
#   'classifierParams': '3.1.0',
#   'modified': '2022-09-28T20:09:16.142Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 37,
#   'classifierName': 'ElasticcLive',
#   'classifierParams': 'XGBUnified+Parsnip04',
#   'modified': '2022-09-28T15:30:10.718Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 36,
#   'classifierName': 'ElasticcLiveSNGuess',
#   'classifierParams': 'XGBUnified+Parsnip04',
#   'modified': '2022-09-28T15:30:10.718Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 64,
#   'classifierName': 'ElasticcLiveSNGuess',
#   'classifierParams': 'XGBUnified+Parsnip05',
#   'modified': '2022-10-17T22:31:05.262Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 38,
#   'classifierName': 'ElasticcLiveSNGuessParsnip',
#   'classifierParams': 'XGBUnified+Parsnip04',
#   'modified': '2022-09-28T15:30:12.004Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 65,
#   'classifierName': 'ElasticcLiveSNGuessParsnip',
#   'classifierParams': 'XGBUnified+Parsnip05',
#   'modified': '2022-10-17T22:32:48.703Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 39,
#   'classifierName': 'ElasticcLiveSNGuessParsnipPrior',
#   'classifierParams': 'XGBUnified+Parsnip04',
#   'modified': '2022-09-28T15:30:12.004Z'},
#  {'brokerName': 'AMPEL',
#   'brokerVersion': 'v0.2',
#   'classifierId': 66,
#   'classifierName': 'ElasticcLiveSNGuessParsnipPrior',
#   'classifierParams': 'XGBUnified+Parsnip05',
#   'modified': '2022-10-17T22:32:48.703Z'},
#  {'brokerName': 'ANTARES',
#   'brokerVersion': '2.0.0',
#   'classifierId': 55,
#   'classifierName': 'Astrorapid_filter',
#   'classifierParams': 'known_redshift=True',
#   'modified': '2022-09-28T23:49:33.522Z'},
#  {'brokerName': 'ANTARES',
#   'brokerVersion': '2.0.0',
#   'classifierId': 44,
#   'classifierName': 'LiCuParsnip_filter',
#   'classifierParams': 'v2',
#   'modified': '2022-09-28T22:39:47.750Z'},
#  {'brokerName': 'ANTARES',
#   'brokerVersion': '2.0.0',
#   'classifierId': 43,
#   'classifierName': 'LightGBM_filter',
#   'classifierParams': 'v3',
#   'modified': '2022-09-28T22:39:47.750Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 45,
#   'classifierName': 'AGN classifier version 1.0',
#   'classifierParams': 'Probability to be an AGN based on a Random Forest '
#                       'classifier',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 46,
#   'classifierName': 'AGN classifier version 1.0',
#   'classifierParams': 'Probability to NOT be an AGN based on a Random Forest '
#                       'classifier',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 50,
#   'classifierName': 'CATS broad classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on the CBPF Algorithm for '
#                       'Transient Search',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 51,
#   'classifierName': 'CATS fine classifier version 1.0',
#   'classifierParams': 'Level 2 classifier based on the CBPF Algorithm for '
#                       'Transient Search',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 52,
#   'classifierName': 'EarlySN classifier version 1.0',
#   'classifierParams': 'Probability to be an early SN Ia based on a Random '
#                       'Forest classifier',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 53,
#   'classifierName': 'EarlySN classifier version 1.0',
#   'classifierParams': 'Probability to NOT be an early SN Ia based on a Random '
#                       'Forest classifier',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 47,
#   'classifierName': 'SuperNNova SN Ia classifier version 1.0',
#   'classifierParams': 'Probability to be a SN Ia based on SuperNNova',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 48,
#   'classifierName': 'SuperNNova SN Ia classifier version 1.0',
#   'classifierParams': 'Probability to NOT be a SN Ia based on SuperNNova',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 49,
#   'classifierName': 'SuperNNova broad classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on SuperNNova',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.4',
#   'classifierId': 54,
#   'classifierName': 'T2 classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on Time-Series Transformer',
#   'modified': '2022-09-28T23:08:00.438Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 56,
#   'classifierName': 'AGN classifier',
#   'classifierParams': 'version 1.0',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 63,
#   'classifierName': 'AGN classifier',
#   'classifierParams': 'version 1.1',
#   'modified': '2022-10-12T01:03:42.602Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 59,
#   'classifierName': 'CATS broad classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on the CBPF Algorithm for '
#                       'Transient Search',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 60,
#   'classifierName': 'CATS fine classifier version 1.0',
#   'classifierParams': 'Level 2 classifier based on the CBPF Algorithm for '
#                       'Transient Search',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 61,
#   'classifierName': 'EarlySN classifier',
#   'classifierParams': 'version 1.0',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 57,
#   'classifierName': 'SuperNNova SN Ia classifier',
#   'classifierParams': 'version 1.0',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 58,
#   'classifierName': 'SuperNNova broad classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on SuperNNova',
#   'modified': '2022-10-04T20:24:12.944Z'},
#  {'brokerName': 'Fink',
#   'brokerVersion': '2.5',
#   'classifierId': 62,
#   'classifierName': 'T2 classifier version 1.0',
#   'classifierParams': 'Level 1 classifier based on Time-Series Transformer',
#   'modified': '2022-10-04T20:24:12.944Z'}]
# Hello, world.
# [2022-10-20 08:45:10,333 - INFO] ConfMatrixClient found 31 classifiers.
# [2022-10-20 08:45:10,334 - INFO] Getting classifications for ALeRCE 1.0.0 messi
# [2022-10-20 08:48:06,545 - INFO] [{'n': 3602, 'pred_class': 110, 'true_class': 111},
#  {'n': 802, 'pred_class': 110, 'true_class': 112},
#  {'n': 6222, 'pred_class': 110, 'true_class': 113},
#  {'n': 27, 'pred_class': 110, 'true_class': 114},
#  {'n': 23, 'pred_class': 110, 'true_class': 115},
#  {'n': 17, 'pred_class': 110, 'true_class': 131},
#  {'n': 11, 'pred_class': 110, 'true_class': 132},
#  {'n': 2, 'pred_class': 110, 'true_class': 133},
#  {'n': 11, 'pred_class': 110, 'true_class': 134},
#  {'n': 2, 'pred_class': 110, 'true_class': 214},
#  {'n': 447, 'pred_class': 110, 'true_class': 221},
#  {'n': 34505, 'pred_class': 111, 'true_class': 111},
#  {'n': 1969, 'pred_class': 111, 'true_class': 112},
#  {'n': 3211, 'pred_class': 111, 'true_class': 113},
#  {'n': 225, 'pred_class': 111, 'true_class': 114},
#  {'n': 81, 'pred_class': 111, 'true_class': 115},
#  {'n': 14, 'pred_class': 111, 'true_class': 131},
#  {'n': 9, 'pred_class': 111, 'true_class': 132},
#  {'n': 1, 'pred_class': 111, 'true_class': 133},
#  {'n': 18, 'pred_class': 111, 'true_class': 134},
#  {'n': 1, 'pred_class': 111, 'true_class': 135},
#  {'n': 149, 'pred_class': 111, 'true_class': 221},
#  {'n': 15001, 'pred_class': 112, 'true_class': 111},
#  {'n': 6662, 'pred_class': 112, 'true_class': 112},
#  {'n': 8779, 'pred_class': 112, 'true_class': 113},
#  {'n': 154, 'pred_class': 112, 'true_class': 114},
#  {'n': 646, 'pred_class': 112, 'true_class': 115},
#  {'n': 27, 'pred_class': 112, 'true_class': 131},
#  {'n': 4, 'pred_class': 112, 'true_class': 132},
#  {'n': 1, 'pred_class': 112, 'true_class': 133},
#  {'n': 20, 'pred_class': 112, 'true_class': 134},
#  {'n': 2, 'pred_class': 112, 'true_class': 212},
#  {'n': 86, 'pred_class': 112, 'true_class': 221},
#  {'n': 56944, 'pred_class': 113, 'true_class': 111},
#  {'n': 6882, 'pred_class': 113, 'true_class': 112},
#  {'n': 66837, 'pred_class': 113, 'true_class': 113},
#  {'n': 782, 'pred_class': 113, 'true_class': 114},
#  {'n': 284, 'pred_class': 113, 'true_class': 115},
#  {'n': 1, 'pred_class': 113, 'true_class': 123},
#  {'n': 934, 'pred_class': 113, 'true_class': 131},
#  {'n': 144, 'pred_class': 113, 'true_class': 132},
#  {'n': 20, 'pred_class': 113, 'true_class': 133},
#  {'n': 153, 'pred_class': 113, 'true_class': 134},
#  {'n': 4, 'pred_class': 113, 'true_class': 135},
#  {'n': 3, 'pred_class': 113, 'true_class': 212},
#  {'n': 430, 'pred_class': 113, 'true_class': 221},
#  {'n': 20748, 'pred_class': 114, 'true_class': 111},
#  {'n': 3519, 'pred_class': 114, 'true_class': 112},
#  {'n': 12659, 'pred_class': 114, 'true_class': 113},
#  {'n': 1506, 'pred_class': 114, 'true_class': 114},
#  {'n': 412, 'pred_class': 114, 'true_class': 115},
#  {'n': 149, 'pred_class': 114, 'true_class': 131},
#  {'n': 34, 'pred_class': 114, 'true_class': 132},
#  {'n': 1, 'pred_class': 114, 'true_class': 133},
#  {'n': 152, 'pred_class': 114, 'true_class': 134},
#  {'n': 1, 'pred_class': 114, 'true_class': 212},
#  {'n': 1, 'pred_class': 114, 'true_class': 214},
#  {'n': 32, 'pred_class': 114, 'true_class': 221},
#  {'n': 3447, 'pred_class': 115, 'true_class': 111},
#  {'n': 1134, 'pred_class': 115, 'true_class': 112},
#  {'n': 1777, 'pred_class': 115, 'true_class': 113},
#  {'n': 129, 'pred_class': 115, 'true_class': 114},
#  {'n': 667, 'pred_class': 115, 'true_class': 115},
#  {'n': 4, 'pred_class': 115, 'true_class': 131},
#  {'n': 4, 'pred_class': 115, 'true_class': 132},
#  {'n': 4, 'pred_class': 115, 'true_class': 133},
#  {'n': 20, 'pred_class': 115, 'true_class': 134},
#  {'n': 1, 'pred_class': 115, 'true_class': 212},
#  {'n': 305, 'pred_class': 115, 'true_class': 221},
#  {'n': 130, 'pred_class': 121, 'true_class': 111},
#  {'n': 28, 'pred_class': 121, 'true_class': 112},
#  {'n': 114, 'pred_class': 121, 'true_class': 113},
#  {'n': 3, 'pred_class': 121, 'true_class': 114},
#  {'n': 8, 'pred_class': 121, 'true_class': 115},
#  {'n': 1, 'pred_class': 121, 'true_class': 131},
#  {'n': 1, 'pred_class': 121, 'true_class': 132},
#  {'n': 37, 'pred_class': 122, 'true_class': 111},
#  {'n': 7, 'pred_class': 122, 'true_class': 112},
#  {'n': 74, 'pred_class': 122, 'true_class': 113},
#  {'n': 1, 'pred_class': 122, 'true_class': 114},
#  {'n': 2, 'pred_class': 122, 'true_class': 115},
#  {'n': 72, 'pred_class': 122, 'true_class': 122},
#  {'n': 1, 'pred_class': 122, 'true_class': 124},
#  {'n': 1, 'pred_class': 122, 'true_class': 131},
#  {'n': 2, 'pred_class': 122, 'true_class': 132},
#  {'n': 1, 'pred_class': 122, 'true_class': 134},
#  {'n': 3, 'pred_class': 122, 'true_class': 211},
#  {'n': 54, 'pred_class': 122, 'true_class': 212},
#  {'n': 10, 'pred_class': 122, 'true_class': 213},
#  {'n': 84, 'pred_class': 122, 'true_class': 214},
#  {'n': 1, 'pred_class': 122, 'true_class': 221},
#  {'n': 28, 'pred_class': 123, 'true_class': 111},
#  {'n': 2, 'pred_class': 123, 'true_class': 112},
#  {'n': 16, 'pred_class': 123, 'true_class': 113},
#  {'n': 1, 'pred_class': 123, 'true_class': 114},
#  {'n': 22, 'pred_class': 123, 'true_class': 122},
#  {'n': 321, 'pred_class': 123, 'true_class': 123},
#  {'n': 10, 'pred_class': 123, 'true_class': 124},
#  {'n': 3, 'pred_class': 123, 'true_class': 131},
#  {'n': 82, 'pred_class': 123, 'true_class': 211},
#  {'n': 770, 'pred_class': 123, 'true_class': 212},
#  {'n': 151, 'pred_class': 123, 'true_class': 213},
#  {'n': 473, 'pred_class': 123, 'true_class': 214},
#  {'n': 1, 'pred_class': 123, 'true_class': 221},
#  {'n': 87, 'pred_class': 124, 'true_class': 111},
#  {'n': 60, 'pred_class': 124, 'true_class': 112},
#  {'n': 134, 'pred_class': 124, 'true_class': 113},
#  {'n': 8, 'pred_class': 124, 'true_class': 114},
#  {'n': 35, 'pred_class': 124, 'true_class': 115},
#  {'n': 48, 'pred_class': 124, 'true_class': 122},
#  {'n': 52, 'pred_class': 124, 'true_class': 123},
#  {'n': 410, 'pred_class': 124, 'true_class': 124},
#  {'n': 39, 'pred_class': 124, 'true_class': 131},
#  {'n': 2, 'pred_class': 124, 'true_class': 134},
#  {'n': 101, 'pred_class': 124, 'true_class': 211},
#  {'n': 3932, 'pred_class': 124, 'true_class': 212},
#  {'n': 370, 'pred_class': 124, 'true_class': 213},
#  {'n': 3111, 'pred_class': 124, 'true_class': 214},
#  {'n': 8342, 'pred_class': 131, 'true_class': 111},
#  {'n': 1998, 'pred_class': 131, 'true_class': 112},
#  {'n': 7712, 'pred_class': 131, 'true_class': 113},
#  {'n': 298, 'pred_class': 131, 'true_class': 114},
#  {'n': 214, 'pred_class': 131, 'true_class': 115},
#  {'n': 3, 'pred_class': 131, 'true_class': 122},
#  {'n': 1, 'pred_class': 131, 'true_class': 123},
#  {'n': 6, 'pred_class': 131, 'true_class': 124},
#  {'n': 2227, 'pred_class': 131, 'true_class': 131},
#  {'n': 23, 'pred_class': 131, 'true_class': 132},
#  {'n': 13, 'pred_class': 131, 'true_class': 133},
#  {'n': 66, 'pred_class': 131, 'true_class': 134},
#  {'n': 6, 'pred_class': 131, 'true_class': 135},
#  {'n': 17, 'pred_class': 131, 'true_class': 212},
#  {'n': 202, 'pred_class': 131, 'true_class': 214},
#  {'n': 5, 'pred_class': 131, 'true_class': 221},
#  {'n': 7692, 'pred_class': 132, 'true_class': 111},
#  {'n': 1182, 'pred_class': 132, 'true_class': 112},
#  {'n': 26424, 'pred_class': 132, 'true_class': 113},
#  {'n': 859, 'pred_class': 132, 'true_class': 114},
#  {'n': 117, 'pred_class': 132, 'true_class': 115},
#  {'n': 321, 'pred_class': 132, 'true_class': 131},
#  {'n': 1559, 'pred_class': 132, 'true_class': 132},
#  {'n': 15, 'pred_class': 132, 'true_class': 133},
#  {'n': 219, 'pred_class': 132, 'true_class': 134},
#  {'n': 1, 'pred_class': 132, 'true_class': 135},
#  {'n': 8, 'pred_class': 132, 'true_class': 214},
#  {'n': 1237, 'pred_class': 132, 'true_class': 221},
#  {'n': 372, 'pred_class': 133, 'true_class': 111},
#  {'n': 102, 'pred_class': 133, 'true_class': 112},
#  {'n': 621, 'pred_class': 133, 'true_class': 113},
#  {'n': 20, 'pred_class': 133, 'true_class': 114},
#  {'n': 25, 'pred_class': 133, 'true_class': 115},
#  {'n': 41, 'pred_class': 133, 'true_class': 131},
#  {'n': 2, 'pred_class': 133, 'true_class': 132},
#  {'n': 15, 'pred_class': 133, 'true_class': 133},
#  {'n': 14, 'pred_class': 133, 'true_class': 134},
#  {'n': 2, 'pred_class': 133, 'true_class': 135},
#  {'n': 220, 'pred_class': 133, 'true_class': 221},
#  {'n': 1073, 'pred_class': 134, 'true_class': 111},
#  {'n': 437, 'pred_class': 134, 'true_class': 112},
#  {'n': 2200, 'pred_class': 134, 'true_class': 113},
#  {'n': 92, 'pred_class': 134, 'true_class': 114},
#  {'n': 45, 'pred_class': 134, 'true_class': 115},
#  {'n': 1, 'pred_class': 134, 'true_class': 122},
#  {'n': 148, 'pred_class': 134, 'true_class': 131},
#  {'n': 8, 'pred_class': 134, 'true_class': 132},
#  {'n': 1, 'pred_class': 134, 'true_class': 133},
#  {'n': 58, 'pred_class': 134, 'true_class': 134},
#  {'n': 1, 'pred_class': 134, 'true_class': 212},
#  {'n': 1, 'pred_class': 134, 'true_class': 214},
#  {'n': 8, 'pred_class': 134, 'true_class': 221},
#  {'n': 15794, 'pred_class': 135, 'true_class': 111},
#  {'n': 2469, 'pred_class': 135, 'true_class': 112},
#  {'n': 7764, 'pred_class': 135, 'true_class': 113},
#  {'n': 649, 'pred_class': 135, 'true_class': 114},
#  {'n': 700, 'pred_class': 135, 'true_class': 115},
#  {'n': 1377, 'pred_class': 135, 'true_class': 131},
#  {'n': 54, 'pred_class': 135, 'true_class': 132},
#  {'n': 33, 'pred_class': 135, 'true_class': 133},
#  {'n': 126, 'pred_class': 135, 'true_class': 134},
#  {'n': 58, 'pred_class': 135, 'true_class': 135},
#  {'n': 1, 'pred_class': 135, 'true_class': 211},
#  {'n': 1, 'pred_class': 135, 'true_class': 212},
#  {'n': 25, 'pred_class': 135, 'true_class': 221},
#  {'n': 179, 'pred_class': 211, 'true_class': 111},
#  {'n': 39, 'pred_class': 211, 'true_class': 112},
#  {'n': 130, 'pred_class': 211, 'true_class': 113},
#  {'n': 12, 'pred_class': 211, 'true_class': 114},
#  {'n': 8, 'pred_class': 211, 'true_class': 115},
#  {'n': 1, 'pred_class': 211, 'true_class': 122},
#  {'n': 7, 'pred_class': 211, 'true_class': 124},
#  {'n': 1, 'pred_class': 211, 'true_class': 131},
#  {'n': 1, 'pred_class': 211, 'true_class': 132},
#  {'n': 1, 'pred_class': 211, 'true_class': 134},
#  {'n': 610, 'pred_class': 211, 'true_class': 211},
#  {'n': 1283, 'pred_class': 211, 'true_class': 212},
#  {'n': 259, 'pred_class': 211, 'true_class': 213},
#  {'n': 197, 'pred_class': 211, 'true_class': 214},
#  {'n': 24, 'pred_class': 211, 'true_class': 221},
#  {'n': 92, 'pred_class': 212, 'true_class': 111},
#  {'n': 36, 'pred_class': 212, 'true_class': 112},
#  {'n': 85, 'pred_class': 212, 'true_class': 113},
#  {'n': 9, 'pred_class': 212, 'true_class': 114},
#  {'n': 23, 'pred_class': 212, 'true_class': 115},
#  {'n': 12, 'pred_class': 212, 'true_class': 122},
#  {'n': 8, 'pred_class': 212, 'true_class': 123},
#  {'n': 16, 'pred_class': 212, 'true_class': 124},
#  {'n': 1, 'pred_class': 212, 'true_class': 131},
#  {'n': 45, 'pred_class': 212, 'true_class': 211},
#  {'n': 21192, 'pred_class': 212, 'true_class': 212},
#  {'n': 615, 'pred_class': 212, 'true_class': 213},
#  {'n': 2011, 'pred_class': 212, 'true_class': 214},
#  {'n': 5, 'pred_class': 212, 'true_class': 221},
#  {'n': 72, 'pred_class': 213, 'true_class': 111},
#  {'n': 17, 'pred_class': 213, 'true_class': 112},
#  {'n': 27, 'pred_class': 213, 'true_class': 113},
#  {'n': 1, 'pred_class': 213, 'true_class': 114},
#  {'n': 2, 'pred_class': 213, 'true_class': 115},
#  {'n': 10, 'pred_class': 213, 'true_class': 122},
#  {'n': 7, 'pred_class': 213, 'true_class': 123},
#  {'n': 13, 'pred_class': 213, 'true_class': 124},
#  {'n': 77, 'pred_class': 213, 'true_class': 211},
#  {'n': 5703, 'pred_class': 213, 'true_class': 212},
#  {'n': 4790, 'pred_class': 213, 'true_class': 213},
#  {'n': 2698, 'pred_class': 213, 'true_class': 214},
#  {'n': 10, 'pred_class': 213, 'true_class': 221},
#  {'n': 4, 'pred_class': 214, 'true_class': 111},
#  {'n': 1, 'pred_class': 214, 'true_class': 112},
#  {'n': 1, 'pred_class': 214, 'true_class': 114},
#  {'n': 51, 'pred_class': 214, 'true_class': 122},
#  {'n': 3, 'pred_class': 214, 'true_class': 123},
#  {'n': 15, 'pred_class': 214, 'true_class': 124},
#  {'n': 13, 'pred_class': 214, 'true_class': 131},
#  {'n': 21, 'pred_class': 214, 'true_class': 211},
#  {'n': 5539, 'pred_class': 214, 'true_class': 212},
#  {'n': 1105, 'pred_class': 214, 'true_class': 213},
#  {'n': 52520, 'pred_class': 214, 'true_class': 214},
#  {'n': 108391, 'pred_class': 221, 'true_class': 111},
#  {'n': 29166, 'pred_class': 221, 'true_class': 112},
#  {'n': 124555, 'pred_class': 221, 'true_class': 113},
#  {'n': 2922, 'pred_class': 221, 'true_class': 114},
#  {'n': 2945, 'pred_class': 221, 'true_class': 115},
#  {'n': 8, 'pred_class': 221, 'true_class': 121},
#  {'n': 336, 'pred_class': 221, 'true_class': 131},
#  {'n': 411, 'pred_class': 221, 'true_class': 132},
#  {'n': 85, 'pred_class': 221, 'true_class': 133},
#  {'n': 498, 'pred_class': 221, 'true_class': 134},
#  {'n': 5, 'pred_class': 221, 'true_class': 135},
#  {'n': 2, 'pred_class': 221, 'true_class': 212},
#  {'n': 1, 'pred_class': 221, 'true_class': 214},
#  {'n': 30914, 'pred_class': 221, 'true_class': 221}]
# [2022-10-20 08:48:06,549 - INFO] Getting classifications for ALeRCE 2.0.1 toretto
# [2022-10-20 08:50:48,040 - INFO] [{'n': 1352, 'pred_class': 110, 'true_class': 111},
#  {'n': 881, 'pred_class': 110, 'true_class': 112},
#  {'n': 1822, 'pred_class': 110, 'true_class': 113},
#  {'n': 47, 'pred_class': 110, 'true_class': 114},
#  {'n': 41, 'pred_class': 110, 'true_class': 115},
#  {'n': 8, 'pred_class': 110, 'true_class': 131},
#  {'n': 2, 'pred_class': 110, 'true_class': 132},
#  {'n': 6, 'pred_class': 110, 'true_class': 134},
#  {'n': 6, 'pred_class': 110, 'true_class': 221},
#  {'n': 117546, 'pred_class': 111, 'true_class': 111},
#  {'n': 9304, 'pred_class': 111, 'true_class': 112},
#  {'n': 23807, 'pred_class': 111, 'true_class': 113},
#  {'n': 1068, 'pred_class': 111, 'true_class': 114},
#  {'n': 279, 'pred_class': 111, 'true_class': 115},
#  {'n': 247, 'pred_class': 111, 'true_class': 131},
#  {'n': 42, 'pred_class': 111, 'true_class': 132},
#  {'n': 75, 'pred_class': 111, 'true_class': 134},
#  {'n': 1, 'pred_class': 111, 'true_class': 135},
#  {'n': 192, 'pred_class': 111, 'true_class': 221},
#  {'n': 2880, 'pred_class': 112, 'true_class': 111},
#  {'n': 7347, 'pred_class': 112, 'true_class': 112},
#  {'n': 4256, 'pred_class': 112, 'true_class': 113},
#  {'n': 62, 'pred_class': 112, 'true_class': 114},
#  {'n': 500, 'pred_class': 112, 'true_class': 115},
#  {'n': 91, 'pred_class': 112, 'true_class': 131},
#  {'n': 1, 'pred_class': 112, 'true_class': 132},
#  {'n': 1, 'pred_class': 112, 'true_class': 133},
#  {'n': 12, 'pred_class': 112, 'true_class': 134},
#  {'n': 9, 'pred_class': 112, 'true_class': 221},
#  {'n': 3207, 'pred_class': 113, 'true_class': 111},
#  {'n': 621, 'pred_class': 113, 'true_class': 112},
#  {'n': 26848, 'pred_class': 113, 'true_class': 113},
#  {'n': 158, 'pred_class': 113, 'true_class': 114},
#  {'n': 15, 'pred_class': 113, 'true_class': 115},
#  {'n': 81, 'pred_class': 113, 'true_class': 131},
#  {'n': 43, 'pred_class': 113, 'true_class': 132},
#  {'n': 48, 'pred_class': 113, 'true_class': 134},
#  {'n': 1, 'pred_class': 113, 'true_class': 135},
#  {'n': 56, 'pred_class': 113, 'true_class': 221},
#  {'n': 19541, 'pred_class': 114, 'true_class': 111},
#  {'n': 3026, 'pred_class': 114, 'true_class': 112},
#  {'n': 10623, 'pred_class': 114, 'true_class': 113},
#  {'n': 800, 'pred_class': 114, 'true_class': 114},
#  {'n': 60, 'pred_class': 114, 'true_class': 115},
#  {'n': 61, 'pred_class': 114, 'true_class': 131},
#  {'n': 28, 'pred_class': 114, 'true_class': 132},
#  {'n': 2, 'pred_class': 114, 'true_class': 133},
#  {'n': 43, 'pred_class': 114, 'true_class': 134},
#  {'n': 137, 'pred_class': 114, 'true_class': 221},
#  {'n': 9620, 'pred_class': 115, 'true_class': 111},
#  {'n': 4291, 'pred_class': 115, 'true_class': 112},
#  {'n': 5022, 'pred_class': 115, 'true_class': 113},
#  {'n': 204, 'pred_class': 115, 'true_class': 114},
#  {'n': 2180, 'pred_class': 115, 'true_class': 115},
#  {'n': 24, 'pred_class': 115, 'true_class': 131},
#  {'n': 7, 'pred_class': 115, 'true_class': 132},
#  {'n': 33, 'pred_class': 115, 'true_class': 134},
#  {'n': 37, 'pred_class': 115, 'true_class': 221},
#  {'n': 897, 'pred_class': 121, 'true_class': 111},
#  {'n': 522, 'pred_class': 121, 'true_class': 112},
#  {'n': 3150, 'pred_class': 121, 'true_class': 113},
#  {'n': 91, 'pred_class': 121, 'true_class': 114},
#  {'n': 130, 'pred_class': 121, 'true_class': 115},
#  {'n': 2, 'pred_class': 121, 'true_class': 121},
#  {'n': 7, 'pred_class': 121, 'true_class': 131},
#  {'n': 12, 'pred_class': 121, 'true_class': 132},
#  {'n': 21, 'pred_class': 121, 'true_class': 134},
#  {'n': 89, 'pred_class': 121, 'true_class': 221},
#  {'n': 1, 'pred_class': 122, 'true_class': 124},
#  {'n': 2, 'pred_class': 122, 'true_class': 212},
#  {'n': 11, 'pred_class': 122, 'true_class': 214},
#  {'n': 26, 'pred_class': 123, 'true_class': 111},
#  {'n': 17, 'pred_class': 123, 'true_class': 112},
#  {'n': 42, 'pred_class': 123, 'true_class': 113},
#  {'n': 286, 'pred_class': 123, 'true_class': 123},
#  {'n': 10, 'pred_class': 123, 'true_class': 124},
#  {'n': 171, 'pred_class': 123, 'true_class': 212},
#  {'n': 16, 'pred_class': 123, 'true_class': 213},
#  {'n': 149, 'pred_class': 123, 'true_class': 214},
#  {'n': 1, 'pred_class': 124, 'true_class': 111},
#  {'n': 3, 'pred_class': 124, 'true_class': 113},
#  {'n': 28, 'pred_class': 124, 'true_class': 123},
#  {'n': 372, 'pred_class': 124, 'true_class': 124},
#  {'n': 138, 'pred_class': 124, 'true_class': 131},
#  {'n': 33, 'pred_class': 124, 'true_class': 211},
#  {'n': 520, 'pred_class': 124, 'true_class': 212},
#  {'n': 47, 'pred_class': 124, 'true_class': 213},
#  {'n': 1071, 'pred_class': 124, 'true_class': 214},
#  {'n': 15035, 'pred_class': 131, 'true_class': 111},
#  {'n': 2182, 'pred_class': 131, 'true_class': 112},
#  {'n': 15977, 'pred_class': 131, 'true_class': 113},
#  {'n': 801, 'pred_class': 131, 'true_class': 114},
#  {'n': 278, 'pred_class': 131, 'true_class': 115},
#  {'n': 2330, 'pred_class': 131, 'true_class': 131},
#  {'n': 179, 'pred_class': 131, 'true_class': 132},
#  {'n': 8, 'pred_class': 131, 'true_class': 133},
#  {'n': 137, 'pred_class': 131, 'true_class': 134},
#  {'n': 15, 'pred_class': 131, 'true_class': 135},
#  {'n': 395, 'pred_class': 131, 'true_class': 221},
#  {'n': 1882, 'pred_class': 132, 'true_class': 111},
#  {'n': 411, 'pred_class': 132, 'true_class': 112},
#  {'n': 15299, 'pred_class': 132, 'true_class': 113},
#  {'n': 61, 'pred_class': 132, 'true_class': 114},
#  {'n': 233, 'pred_class': 132, 'true_class': 131},
#  {'n': 693, 'pred_class': 132, 'true_class': 132},
#  {'n': 6, 'pred_class': 132, 'true_class': 133},
#  {'n': 29, 'pred_class': 132, 'true_class': 134},
#  {'n': 2, 'pred_class': 132, 'true_class': 135},
#  {'n': 901, 'pred_class': 132, 'true_class': 221},
#  {'n': 3103, 'pred_class': 133, 'true_class': 111},
#  {'n': 1461, 'pred_class': 133, 'true_class': 112},
#  {'n': 12458, 'pred_class': 133, 'true_class': 113},
#  {'n': 249, 'pred_class': 133, 'true_class': 114},
#  {'n': 109, 'pred_class': 133, 'true_class': 115},
#  {'n': 226, 'pred_class': 133, 'true_class': 131},
#  {'n': 98, 'pred_class': 133, 'true_class': 132},
#  {'n': 59, 'pred_class': 133, 'true_class': 133},
#  {'n': 77, 'pred_class': 133, 'true_class': 134},
#  {'n': 3, 'pred_class': 133, 'true_class': 135},
#  {'n': 3492, 'pred_class': 133, 'true_class': 221},
#  {'n': 14732, 'pred_class': 134, 'true_class': 111},
#  {'n': 5998, 'pred_class': 134, 'true_class': 112},
#  {'n': 28925, 'pred_class': 134, 'true_class': 113},
#  {'n': 1244, 'pred_class': 134, 'true_class': 114},
#  {'n': 558, 'pred_class': 134, 'true_class': 115},
#  {'n': 119, 'pred_class': 134, 'true_class': 131},
#  {'n': 68, 'pred_class': 134, 'true_class': 132},
#  {'n': 6, 'pred_class': 134, 'true_class': 133},
#  {'n': 297, 'pred_class': 134, 'true_class': 134},
#  {'n': 2, 'pred_class': 134, 'true_class': 135},
#  {'n': 511, 'pred_class': 134, 'true_class': 221},
#  {'n': 4755, 'pred_class': 135, 'true_class': 111},
#  {'n': 2603, 'pred_class': 135, 'true_class': 112},
#  {'n': 5872, 'pred_class': 135, 'true_class': 113},
#  {'n': 133, 'pred_class': 135, 'true_class': 114},
#  {'n': 42, 'pred_class': 135, 'true_class': 115},
#  {'n': 985, 'pred_class': 135, 'true_class': 131},
#  {'n': 3, 'pred_class': 135, 'true_class': 132},
#  {'n': 19, 'pred_class': 135, 'true_class': 133},
#  {'n': 23, 'pred_class': 135, 'true_class': 134},
#  {'n': 38, 'pred_class': 135, 'true_class': 135},
#  {'n': 148, 'pred_class': 135, 'true_class': 221},
#  {'n': 2, 'pred_class': 211, 'true_class': 123},
#  {'n': 445, 'pred_class': 211, 'true_class': 211},
#  {'n': 208, 'pred_class': 211, 'true_class': 212},
#  {'n': 60, 'pred_class': 211, 'true_class': 213},
#  {'n': 39, 'pred_class': 211, 'true_class': 214},
#  {'n': 86426, 'pred_class': 212, 'true_class': 111},
#  {'n': 18037, 'pred_class': 212, 'true_class': 112},
#  {'n': 108013, 'pred_class': 212, 'true_class': 113},
#  {'n': 2880, 'pred_class': 212, 'true_class': 114},
#  {'n': 2100, 'pred_class': 212, 'true_class': 115},
#  {'n': 7, 'pred_class': 212, 'true_class': 121},
#  {'n': 241, 'pred_class': 212, 'true_class': 122},
#  {'n': 68, 'pred_class': 212, 'true_class': 123},
#  {'n': 97, 'pred_class': 212, 'true_class': 124},
#  {'n': 990, 'pred_class': 212, 'true_class': 131},
#  {'n': 601, 'pred_class': 212, 'true_class': 132},
#  {'n': 80, 'pred_class': 212, 'true_class': 133},
#  {'n': 544, 'pred_class': 212, 'true_class': 134},
#  {'n': 15, 'pred_class': 212, 'true_class': 135},
#  {'n': 465, 'pred_class': 212, 'true_class': 211},
#  {'n': 35516, 'pred_class': 212, 'true_class': 212},
#  {'n': 1709, 'pred_class': 212, 'true_class': 213},
#  {'n': 16761, 'pred_class': 212, 'true_class': 214},
#  {'n': 9415, 'pred_class': 212, 'true_class': 221},
#  {'n': 3, 'pred_class': 213, 'true_class': 123},
#  {'n': 1, 'pred_class': 213, 'true_class': 124},
#  {'n': 14, 'pred_class': 213, 'true_class': 211},
#  {'n': 861, 'pred_class': 213, 'true_class': 212},
#  {'n': 5342, 'pred_class': 213, 'true_class': 213},
#  {'n': 559, 'pred_class': 213, 'true_class': 214},
#  {'n': 1, 'pred_class': 214, 'true_class': 111},
#  {'n': 1, 'pred_class': 214, 'true_class': 113},
#  {'n': 8, 'pred_class': 214, 'true_class': 123},
#  {'n': 2, 'pred_class': 214, 'true_class': 131},
#  {'n': 5, 'pred_class': 214, 'true_class': 211},
#  {'n': 1389, 'pred_class': 214, 'true_class': 212},
#  {'n': 186, 'pred_class': 214, 'true_class': 213},
#  {'n': 44244, 'pred_class': 214, 'true_class': 214},
#  {'n': 2421, 'pred_class': 221, 'true_class': 111},
#  {'n': 999, 'pred_class': 221, 'true_class': 112},
#  {'n': 18056, 'pred_class': 221, 'true_class': 113},
#  {'n': 157, 'pred_class': 221, 'true_class': 114},
#  {'n': 39, 'pred_class': 221, 'true_class': 115},
#  {'n': 186, 'pred_class': 221, 'true_class': 131},
#  {'n': 567, 'pred_class': 221, 'true_class': 132},
#  {'n': 19, 'pred_class': 221, 'true_class': 133},
#  {'n': 81, 'pred_class': 221, 'true_class': 134},
#  {'n': 1, 'pred_class': 221, 'true_class': 135},
#  {'n': 19585, 'pred_class': 221, 'true_class': 221}]
# [2022-10-20 08:50:48,043 - INFO] Getting classifications for ALeRCE 3.1.0 balto
# [2022-10-20 08:53:39,701 - INFO] [{'n': 2235, 'pred_class': 110, 'true_class': 111},
#  {'n': 886, 'pred_class': 110, 'true_class': 112},
#  {'n': 3807, 'pred_class': 110, 'true_class': 113},
#  {'n': 86, 'pred_class': 110, 'true_class': 114},
#  {'n': 160, 'pred_class': 110, 'true_class': 115},
#  {'n': 1, 'pred_class': 110, 'true_class': 121},
#  {'n': 7, 'pred_class': 110, 'true_class': 131},
#  {'n': 2, 'pred_class': 110, 'true_class': 132},
#  {'n': 1, 'pred_class': 110, 'true_class': 133},
#  {'n': 18, 'pred_class': 110, 'true_class': 134},
#  {'n': 60, 'pred_class': 110, 'true_class': 221},
#  {'n': 90369, 'pred_class': 111, 'true_class': 111},
#  {'n': 7861, 'pred_class': 111, 'true_class': 112},
#  {'n': 20395, 'pred_class': 111, 'true_class': 113},
#  {'n': 1114, 'pred_class': 111, 'true_class': 114},
#  {'n': 270, 'pred_class': 111, 'true_class': 115},
#  {'n': 35, 'pred_class': 111, 'true_class': 131},
#  {'n': 11, 'pred_class': 111, 'true_class': 132},
#  {'n': 2, 'pred_class': 111, 'true_class': 133},
#  {'n': 57, 'pred_class': 111, 'true_class': 134},
#  {'n': 376, 'pred_class': 111, 'true_class': 221},
#  {'n': 27414, 'pred_class': 112, 'true_class': 111},
#  {'n': 17045, 'pred_class': 112, 'true_class': 112},
#  {'n': 17244, 'pred_class': 112, 'true_class': 113},
#  {'n': 373, 'pred_class': 112, 'true_class': 114},
#  {'n': 2225, 'pred_class': 112, 'true_class': 115},
#  {'n': 104, 'pred_class': 112, 'true_class': 131},
#  {'n': 4, 'pred_class': 112, 'true_class': 132},
#  {'n': 4, 'pred_class': 112, 'true_class': 133},
#  {'n': 75, 'pred_class': 112, 'true_class': 134},
#  {'n': 1, 'pred_class': 112, 'true_class': 135},
#  {'n': 387, 'pred_class': 112, 'true_class': 221},
#  {'n': 60975, 'pred_class': 113, 'true_class': 111},
#  {'n': 6575, 'pred_class': 113, 'true_class': 112},
#  {'n': 97472, 'pred_class': 113, 'true_class': 113},
#  {'n': 1246, 'pred_class': 113, 'true_class': 114},
#  {'n': 280, 'pred_class': 113, 'true_class': 115},
#  {'n': 658, 'pred_class': 113, 'true_class': 131},
#  {'n': 143, 'pred_class': 113, 'true_class': 132},
#  {'n': 18, 'pred_class': 113, 'true_class': 133},
#  {'n': 241, 'pred_class': 113, 'true_class': 134},
#  {'n': 2, 'pred_class': 113, 'true_class': 135},
#  {'n': 308, 'pred_class': 113, 'true_class': 221},
#  {'n': 9154, 'pred_class': 114, 'true_class': 111},
#  {'n': 2278, 'pred_class': 114, 'true_class': 112},
#  {'n': 9336, 'pred_class': 114, 'true_class': 113},
#  {'n': 1316, 'pred_class': 114, 'true_class': 114},
#  {'n': 400, 'pred_class': 114, 'true_class': 115},
#  {'n': 149, 'pred_class': 114, 'true_class': 131},
#  {'n': 25, 'pred_class': 114, 'true_class': 132},
#  {'n': 6, 'pred_class': 114, 'true_class': 133},
#  {'n': 122, 'pred_class': 114, 'true_class': 134},
#  {'n': 457, 'pred_class': 114, 'true_class': 221},
#  {'n': 165, 'pred_class': 115, 'true_class': 111},
#  {'n': 187, 'pred_class': 115, 'true_class': 112},
#  {'n': 257, 'pred_class': 115, 'true_class': 113},
#  {'n': 10, 'pred_class': 115, 'true_class': 114},
#  {'n': 614, 'pred_class': 115, 'true_class': 115},
#  {'n': 2, 'pred_class': 115, 'true_class': 131},
#  {'n': 3, 'pred_class': 115, 'true_class': 132},
#  {'n': 3, 'pred_class': 115, 'true_class': 134},
#  {'n': 1, 'pred_class': 115, 'true_class': 135},
#  {'n': 379, 'pred_class': 115, 'true_class': 221},
#  {'n': 5, 'pred_class': 121, 'true_class': 111},
#  {'n': 3, 'pred_class': 121, 'true_class': 112},
#  {'n': 16, 'pred_class': 121, 'true_class': 113},
#  {'n': 1, 'pred_class': 121, 'true_class': 114},
#  {'n': 6, 'pred_class': 121, 'true_class': 115},
#  {'n': 1, 'pred_class': 121, 'true_class': 133},
#  {'n': 1, 'pred_class': 121, 'true_class': 212},
#  {'n': 17, 'pred_class': 122, 'true_class': 111},
#  {'n': 4, 'pred_class': 122, 'true_class': 112},
#  {'n': 10, 'pred_class': 122, 'true_class': 113},
#  {'n': 1, 'pred_class': 122, 'true_class': 114},
#  {'n': 2, 'pred_class': 122, 'true_class': 115},
#  {'n': 106, 'pred_class': 122, 'true_class': 122},
#  {'n': 36, 'pred_class': 122, 'true_class': 212},
#  {'n': 10, 'pred_class': 122, 'true_class': 213},
#  {'n': 34, 'pred_class': 122, 'true_class': 214},
#  {'n': 30, 'pred_class': 123, 'true_class': 111},
#  {'n': 6, 'pred_class': 123, 'true_class': 112},
#  {'n': 12, 'pred_class': 123, 'true_class': 113},
#  {'n': 10, 'pred_class': 123, 'true_class': 122},
#  {'n': 365, 'pred_class': 123, 'true_class': 123},
#  {'n': 7, 'pred_class': 123, 'true_class': 124},
#  {'n': 1, 'pred_class': 123, 'true_class': 131},
#  {'n': 41, 'pred_class': 123, 'true_class': 211},
#  {'n': 908, 'pred_class': 123, 'true_class': 212},
#  {'n': 72, 'pred_class': 123, 'true_class': 213},
#  {'n': 312, 'pred_class': 123, 'true_class': 214},
#  {'n': 23, 'pred_class': 124, 'true_class': 111},
#  {'n': 10, 'pred_class': 124, 'true_class': 112},
#  {'n': 17, 'pred_class': 124, 'true_class': 113},
#  {'n': 1, 'pred_class': 124, 'true_class': 115},
#  {'n': 63, 'pred_class': 124, 'true_class': 122},
#  {'n': 35, 'pred_class': 124, 'true_class': 123},
#  {'n': 444, 'pred_class': 124, 'true_class': 124},
#  {'n': 55, 'pred_class': 124, 'true_class': 131},
#  {'n': 101, 'pred_class': 124, 'true_class': 211},
#  {'n': 1700, 'pred_class': 124, 'true_class': 212},
#  {'n': 187, 'pred_class': 124, 'true_class': 213},
#  {'n': 3321, 'pred_class': 124, 'true_class': 214},
#  {'n': 1, 'pred_class': 124, 'true_class': 221},
#  {'n': 32211, 'pred_class': 131, 'true_class': 111},
#  {'n': 6347, 'pred_class': 131, 'true_class': 112},
#  {'n': 34987, 'pred_class': 131, 'true_class': 113},
#  {'n': 638, 'pred_class': 131, 'true_class': 114},
#  {'n': 295, 'pred_class': 131, 'true_class': 115},
#  {'n': 1, 'pred_class': 131, 'true_class': 122},
#  {'n': 1, 'pred_class': 131, 'true_class': 124},
#  {'n': 2910, 'pred_class': 131, 'true_class': 131},
#  {'n': 95, 'pred_class': 131, 'true_class': 132},
#  {'n': 39, 'pred_class': 131, 'true_class': 133},
#  {'n': 205, 'pred_class': 131, 'true_class': 134},
#  {'n': 8, 'pred_class': 131, 'true_class': 135},
#  {'n': 2, 'pred_class': 131, 'true_class': 212},
#  {'n': 61, 'pred_class': 131, 'true_class': 214},
#  {'n': 46, 'pred_class': 131, 'true_class': 221},
#  {'n': 8221, 'pred_class': 132, 'true_class': 111},
#  {'n': 1670, 'pred_class': 132, 'true_class': 112},
#  {'n': 49726, 'pred_class': 132, 'true_class': 113},
#  {'n': 1003, 'pred_class': 132, 'true_class': 114},
#  {'n': 156, 'pred_class': 132, 'true_class': 115},
#  {'n': 2, 'pred_class': 132, 'true_class': 121},
#  {'n': 225, 'pred_class': 132, 'true_class': 131},
#  {'n': 1917, 'pred_class': 132, 'true_class': 132},
#  {'n': 40, 'pred_class': 132, 'true_class': 133},
#  {'n': 270, 'pred_class': 132, 'true_class': 134},
#  {'n': 1, 'pred_class': 132, 'true_class': 135},
#  {'n': 1, 'pred_class': 132, 'true_class': 212},
#  {'n': 3, 'pred_class': 132, 'true_class': 214},
#  {'n': 2699, 'pred_class': 132, 'true_class': 221},
#  {'n': 2244, 'pred_class': 133, 'true_class': 111},
#  {'n': 529, 'pred_class': 133, 'true_class': 112},
#  {'n': 3814, 'pred_class': 133, 'true_class': 113},
#  {'n': 67, 'pred_class': 133, 'true_class': 114},
#  {'n': 30, 'pred_class': 133, 'true_class': 115},
#  {'n': 16, 'pred_class': 133, 'true_class': 131},
#  {'n': 6, 'pred_class': 133, 'true_class': 132},
#  {'n': 11, 'pred_class': 133, 'true_class': 133},
#  {'n': 10, 'pred_class': 133, 'true_class': 134},
#  {'n': 1, 'pred_class': 133, 'true_class': 135},
#  {'n': 1, 'pred_class': 133, 'true_class': 212},
#  {'n': 458, 'pred_class': 133, 'true_class': 221},
#  {'n': 1338, 'pred_class': 134, 'true_class': 111},
#  {'n': 1416, 'pred_class': 134, 'true_class': 112},
#  {'n': 3658, 'pred_class': 134, 'true_class': 113},
#  {'n': 152, 'pred_class': 134, 'true_class': 114},
#  {'n': 130, 'pred_class': 134, 'true_class': 115},
#  {'n': 414, 'pred_class': 134, 'true_class': 131},
#  {'n': 1, 'pred_class': 134, 'true_class': 132},
#  {'n': 1, 'pred_class': 134, 'true_class': 133},
#  {'n': 94, 'pred_class': 134, 'true_class': 134},
#  {'n': 1, 'pred_class': 134, 'true_class': 135},
#  {'n': 1, 'pred_class': 134, 'true_class': 212},
#  {'n': 1, 'pred_class': 134, 'true_class': 221},
#  {'n': 44806, 'pred_class': 135, 'true_class': 111},
#  {'n': 9186, 'pred_class': 135, 'true_class': 112},
#  {'n': 22284, 'pred_class': 135, 'true_class': 113},
#  {'n': 1626, 'pred_class': 135, 'true_class': 114},
#  {'n': 1190, 'pred_class': 135, 'true_class': 115},
#  {'n': 1193, 'pred_class': 135, 'true_class': 131},
#  {'n': 76, 'pred_class': 135, 'true_class': 132},
#  {'n': 43, 'pred_class': 135, 'true_class': 133},
#  {'n': 232, 'pred_class': 135, 'true_class': 134},
#  {'n': 66, 'pred_class': 135, 'true_class': 135},
#  {'n': 4, 'pred_class': 135, 'true_class': 221},
#  {'n': 6, 'pred_class': 211, 'true_class': 111},
#  {'n': 11, 'pred_class': 211, 'true_class': 122},
#  {'n': 6, 'pred_class': 211, 'true_class': 123},
#  {'n': 1, 'pred_class': 211, 'true_class': 124},
#  {'n': 683, 'pred_class': 211, 'true_class': 211},
#  {'n': 526, 'pred_class': 211, 'true_class': 212},
#  {'n': 256, 'pred_class': 211, 'true_class': 213},
#  {'n': 213, 'pred_class': 211, 'true_class': 214},
#  {'n': 1, 'pred_class': 211, 'true_class': 221},
#  {'n': 6, 'pred_class': 212, 'true_class': 111},
#  {'n': 3, 'pred_class': 212, 'true_class': 112},
#  {'n': 3, 'pred_class': 212, 'true_class': 113},
#  {'n': 14, 'pred_class': 212, 'true_class': 122},
#  {'n': 7, 'pred_class': 212, 'true_class': 123},
#  {'n': 18, 'pred_class': 212, 'true_class': 124},
#  {'n': 73, 'pred_class': 212, 'true_class': 211},
#  {'n': 29202, 'pred_class': 212, 'true_class': 212},
#  {'n': 802, 'pred_class': 212, 'true_class': 213},
#  {'n': 3074, 'pred_class': 212, 'true_class': 214},
#  {'n': 1, 'pred_class': 212, 'true_class': 221},
#  {'n': 3, 'pred_class': 213, 'true_class': 111},
#  {'n': 12, 'pred_class': 213, 'true_class': 113},
#  {'n': 20, 'pred_class': 213, 'true_class': 122},
#  {'n': 4, 'pred_class': 213, 'true_class': 123},
#  {'n': 11, 'pred_class': 213, 'true_class': 124},
#  {'n': 1, 'pred_class': 213, 'true_class': 131},
#  {'n': 1, 'pred_class': 213, 'true_class': 134},
#  {'n': 73, 'pred_class': 213, 'true_class': 211},
#  {'n': 5929, 'pred_class': 213, 'true_class': 212},
#  {'n': 5972, 'pred_class': 213, 'true_class': 213},
#  {'n': 6807, 'pred_class': 213, 'true_class': 214},
#  {'n': 3, 'pred_class': 213, 'true_class': 221},
#  {'n': 1, 'pred_class': 214, 'true_class': 112},
#  {'n': 4, 'pred_class': 214, 'true_class': 113},
#  {'n': 29, 'pred_class': 214, 'true_class': 122},
#  {'n': 1, 'pred_class': 214, 'true_class': 123},
#  {'n': 9, 'pred_class': 214, 'true_class': 124},
#  {'n': 5, 'pred_class': 214, 'true_class': 131},
#  {'n': 11, 'pred_class': 214, 'true_class': 211},
#  {'n': 878, 'pred_class': 214, 'true_class': 212},
#  {'n': 123, 'pred_class': 214, 'true_class': 213},
#  {'n': 50551, 'pred_class': 214, 'true_class': 214},
#  {'n': 4, 'pred_class': 214, 'true_class': 221},
#  {'n': 9809, 'pred_class': 221, 'true_class': 111},
#  {'n': 4851, 'pred_class': 221, 'true_class': 112},
#  {'n': 23072, 'pred_class': 221, 'true_class': 113},
#  {'n': 476, 'pred_class': 221, 'true_class': 114},
#  {'n': 692, 'pred_class': 221, 'true_class': 115},
#  {'n': 6, 'pred_class': 221, 'true_class': 121},
#  {'n': 50, 'pred_class': 221, 'true_class': 131},
#  {'n': 102, 'pred_class': 221, 'true_class': 132},
#  {'n': 35, 'pred_class': 221, 'true_class': 133},
#  {'n': 119, 'pred_class': 221, 'true_class': 134},
#  {'n': 30364, 'pred_class': 221, 'true_class': 221}]
# [2022-10-20 08:53:39,705 - INFO] Getting classifications for AMPEL v0.2 ElasticcLive
# [2022-10-20 08:54:01,550 - INFO] [{'n': 58112, 'pred_class': 0, 'true_class': 111},
#  {'n': 14702, 'pred_class': 0, 'true_class': 112},
#  {'n': 74500, 'pred_class': 0, 'true_class': 113},
#  {'n': 1912, 'pred_class': 0, 'true_class': 114},
#  {'n': 1557, 'pred_class': 0, 'true_class': 115},
#  {'n': 1, 'pred_class': 0, 'true_class': 121},
#  {'n': 107, 'pred_class': 0, 'true_class': 122},
#  {'n': 74, 'pred_class': 0, 'true_class': 123},
#  {'n': 80, 'pred_class': 0, 'true_class': 124},
#  {'n': 1158, 'pred_class': 0, 'true_class': 131},
#  {'n': 535, 'pred_class': 0, 'true_class': 132},
#  {'n': 72, 'pred_class': 0, 'true_class': 133},
#  {'n': 371, 'pred_class': 0, 'true_class': 134},
#  {'n': 18, 'pred_class': 0, 'true_class': 135},
#  {'n': 48, 'pred_class': 0, 'true_class': 211},
#  {'n': 4433, 'pred_class': 0, 'true_class': 212},
#  {'n': 875, 'pred_class': 0, 'true_class': 213},
#  {'n': 5882, 'pred_class': 0, 'true_class': 214},
#  {'n': 7545, 'pred_class': 0, 'true_class': 221},
#  {'n': 15, 'pred_class': 21, 'true_class': 124},
#  {'n': 3, 'pred_class': 21, 'true_class': 211},
#  {'n': 489, 'pred_class': 21, 'true_class': 212},
#  {'n': 129, 'pred_class': 21, 'true_class': 213},
#  {'n': 10321, 'pred_class': 21, 'true_class': 214},
#  {'n': 1083, 'pred_class': 21, 'true_class': 221},
#  {'n': 5479, 'pred_class': 22, 'true_class': 221},
#  {'n': 108, 'pred_class': 124, 'true_class': 124},
#  {'n': 136, 'pred_class': 124, 'true_class': 211},
#  {'n': 12891, 'pred_class': 124, 'true_class': 212},
#  {'n': 2496, 'pred_class': 124, 'true_class': 213},
#  {'n': 18322, 'pred_class': 124, 'true_class': 214},
#  {'n': 3600, 'pred_class': 124, 'true_class': 221}]
# [2022-10-20 08:54:01,553 - INFO] Getting classifications for AMPEL v0.2 ElasticcLiveSNGuess
# [2022-10-20 08:54:58,560 - INFO] [{'n': 5755, 'pred_class': 0, 'true_class': 111},
#  {'n': 1581, 'pred_class': 0, 'true_class': 112},
#  {'n': 7629, 'pred_class': 0, 'true_class': 113},
#  {'n': 191, 'pred_class': 0, 'true_class': 114},
#  {'n': 180, 'pred_class': 0, 'true_class': 115},
#  {'n': 9, 'pred_class': 0, 'true_class': 122},
#  {'n': 10, 'pred_class': 0, 'true_class': 123},
#  {'n': 9, 'pred_class': 0, 'true_class': 124},
#  {'n': 134, 'pred_class': 0, 'true_class': 131},
#  {'n': 53, 'pred_class': 0, 'true_class': 132},
#  {'n': 13, 'pred_class': 0, 'true_class': 133},
#  {'n': 48, 'pred_class': 0, 'true_class': 134},
#  {'n': 317, 'pred_class': 0, 'true_class': 212},
#  {'n': 42, 'pred_class': 0, 'true_class': 213},
#  {'n': 832, 'pred_class': 0, 'true_class': 214},
#  {'n': 1229, 'pred_class': 0, 'true_class': 221},
#  {'n': 191498, 'pred_class': 1, 'true_class': 111},
#  {'n': 38544, 'pred_class': 1, 'true_class': 112},
#  {'n': 161750, 'pred_class': 1, 'true_class': 113},
#  {'n': 4674, 'pred_class': 1, 'true_class': 114},
#  {'n': 4197, 'pred_class': 1, 'true_class': 115},
#  {'n': 4, 'pred_class': 1, 'true_class': 121},
#  {'n': 12, 'pred_class': 1, 'true_class': 122},
#  {'n': 114, 'pred_class': 1, 'true_class': 123},
#  {'n': 136, 'pred_class': 1, 'true_class': 124},
#  {'n': 3804, 'pred_class': 1, 'true_class': 131},
#  {'n': 1162, 'pred_class': 1, 'true_class': 132},
#  {'n': 106, 'pred_class': 1, 'true_class': 133},
#  {'n': 804, 'pred_class': 1, 'true_class': 134},
#  {'n': 55, 'pred_class': 1, 'true_class': 135},
#  {'n': 1, 'pred_class': 1, 'true_class': 211},
#  {'n': 87, 'pred_class': 1, 'true_class': 212},
#  {'n': 4, 'pred_class': 1, 'true_class': 213},
#  {'n': 235, 'pred_class': 1, 'true_class': 214},
#  {'n': 6382, 'pred_class': 1, 'true_class': 221},
#  {'n': 5909, 'pred_class': 21, 'true_class': 111},
#  {'n': 520, 'pred_class': 21, 'true_class': 112},
#  {'n': 11543, 'pred_class': 21, 'true_class': 113},
#  {'n': 422, 'pred_class': 21, 'true_class': 114},
#  {'n': 128, 'pred_class': 21, 'true_class': 115},
#  {'n': 55, 'pred_class': 21, 'true_class': 122},
#  {'n': 161, 'pred_class': 21, 'true_class': 123},
#  {'n': 61, 'pred_class': 21, 'true_class': 124},
#  {'n': 714, 'pred_class': 21, 'true_class': 131},
#  {'n': 433, 'pred_class': 21, 'true_class': 132},
#  {'n': 11, 'pred_class': 21, 'true_class': 133},
#  {'n': 89, 'pred_class': 21, 'true_class': 134},
#  {'n': 6, 'pred_class': 21, 'true_class': 135},
#  {'n': 284, 'pred_class': 21, 'true_class': 211},
#  {'n': 26203, 'pred_class': 21, 'true_class': 212},
#  {'n': 5184, 'pred_class': 21, 'true_class': 213},
#  {'n': 32606, 'pred_class': 21, 'true_class': 214},
#  {'n': 5245, 'pred_class': 21, 'true_class': 221},
#  {'n': 3153, 'pred_class': 22, 'true_class': 111},
#  {'n': 468, 'pred_class': 22, 'true_class': 112},
#  {'n': 5164, 'pred_class': 22, 'true_class': 113},
#  {'n': 98, 'pred_class': 22, 'true_class': 114},
#  {'n': 47, 'pred_class': 22, 'true_class': 115},
#  {'n': 62, 'pred_class': 22, 'true_class': 131},
#  {'n': 94, 'pred_class': 22, 'true_class': 132},
#  {'n': 4, 'pred_class': 22, 'true_class': 133},
#  {'n': 17, 'pred_class': 22, 'true_class': 134},
#  {'n': 1, 'pred_class': 22, 'true_class': 135},
#  {'n': 1, 'pred_class': 22, 'true_class': 212},
#  {'n': 9, 'pred_class': 22, 'true_class': 214},
#  {'n': 6348, 'pred_class': 22, 'true_class': 221},
#  {'n': 115, 'pred_class': 124, 'true_class': 124},
#  {'n': 10, 'pred_class': 124, 'true_class': 211},
#  {'n': 878, 'pred_class': 124, 'true_class': 212},
#  {'n': 129, 'pred_class': 124, 'true_class': 213},
#  {'n': 3613, 'pred_class': 124, 'true_class': 214},
#  {'n': 2297, 'pred_class': 124, 'true_class': 221}]
# [2022-10-20 08:54:58,565 - INFO] Getting classifications for AMPEL v0.2 ElasticcLiveSNGuess
# [2022-10-20 08:55:32,167 - INFO] [{'n': 9287, 'pred_class': 0, 'true_class': 111},
#  {'n': 2465, 'pred_class': 0, 'true_class': 112},
#  {'n': 15268, 'pred_class': 0, 'true_class': 113},
#  {'n': 380, 'pred_class': 0, 'true_class': 114},
#  {'n': 268, 'pred_class': 0, 'true_class': 115},
#  {'n': 39, 'pred_class': 0, 'true_class': 122},
#  {'n': 20, 'pred_class': 0, 'true_class': 123},
#  {'n': 37, 'pred_class': 0, 'true_class': 124},
#  {'n': 180, 'pred_class': 0, 'true_class': 131},
#  {'n': 96, 'pred_class': 0, 'true_class': 132},
#  {'n': 12, 'pred_class': 0, 'true_class': 133},
#  {'n': 79, 'pred_class': 0, 'true_class': 134},
#  {'n': 5, 'pred_class': 0, 'true_class': 135},
#  {'n': 172, 'pred_class': 0, 'true_class': 211},
#  {'n': 3107, 'pred_class': 0, 'true_class': 212},
#  {'n': 536, 'pred_class': 0, 'true_class': 213},
#  {'n': 1873, 'pred_class': 0, 'true_class': 214},
#  {'n': 2171, 'pred_class': 0, 'true_class': 221},
#  {'n': 80996, 'pred_class': 1, 'true_class': 111},
#  {'n': 18072, 'pred_class': 1, 'true_class': 112},
#  {'n': 77179, 'pred_class': 1, 'true_class': 113},
#  {'n': 1980, 'pred_class': 1, 'true_class': 114},
#  {'n': 1647, 'pred_class': 1, 'true_class': 115},
#  {'n': 3, 'pred_class': 1, 'true_class': 121},
#  {'n': 1, 'pred_class': 1, 'true_class': 122},
#  {'n': 69, 'pred_class': 1, 'true_class': 123},
#  {'n': 154, 'pred_class': 1, 'true_class': 124},
#  {'n': 2788, 'pred_class': 1, 'true_class': 131},
# ...
#  17  Fink 2.4 T2 classifier version 1.0
#  18  Fink 2.4 T2 classifier version 1.0  ,
#  56:     pred_class  true_class       n  classifier_id          classifier_name
#  0            0         111  221618             56  Fink 2.5 AGN classifier
#  1            0         112   45873             56  Fink 2.5 AGN classifier
#  2            0         113  216402             56  Fink 2.5 AGN classifier
#  3            0         114    6009             56  Fink 2.5 AGN classifier
#  4            0         115    4944             56  Fink 2.5 AGN classifier
#  5            0         121       4             56  Fink 2.5 AGN classifier
#  6            0         122     144             56  Fink 2.5 AGN classifier
#  7            0         123     322             56  Fink 2.5 AGN classifier
#  8            0         124     430             56  Fink 2.5 AGN classifier
#  9            0         131    5145             56  Fink 2.5 AGN classifier
#  10           0         132    1965             56  Fink 2.5 AGN classifier
#  11           0         133     170             56  Fink 2.5 AGN classifier
#  12           0         134    1133             56  Fink 2.5 AGN classifier
#  13           0         135      73             56  Fink 2.5 AGN classifier
#  14           0         211     815             56  Fink 2.5 AGN classifier
#  15           0         212   36662             56  Fink 2.5 AGN classifier
#  16           0         213    6904             56  Fink 2.5 AGN classifier
#  17           0         214   53879             56  Fink 2.5 AGN classifier
#  18           0         221   29759             56  Fink 2.5 AGN classifier
#  19         221         221     473             56  Fink 2.5 AGN classifier,
#  63:     pred_class  true_class       n  classifier_id          classifier_name
#  0            0         111   95040             63  Fink 2.5 AGN classifier
#  1            0         112   20536             63  Fink 2.5 AGN classifier
#  2            0         113   98118             63  Fink 2.5 AGN classifier
#  3            0         114    2534             63  Fink 2.5 AGN classifier
#  4            0         115    1916             63  Fink 2.5 AGN classifier
#  5            0         121       2             63  Fink 2.5 AGN classifier
#  6            0         122      49             63  Fink 2.5 AGN classifier
#  7            0         123     147             63  Fink 2.5 AGN classifier
#  8            0         124     375             63  Fink 2.5 AGN classifier
#  9            0         131    3419             63  Fink 2.5 AGN classifier
#  10           0         132    1057             63  Fink 2.5 AGN classifier
#  11           0         133      89             63  Fink 2.5 AGN classifier
#  12           0         134     515             63  Fink 2.5 AGN classifier
#  13           0         135      52             63  Fink 2.5 AGN classifier
#  14           0         211     777             63  Fink 2.5 AGN classifier
#  15           0         212   32063             63  Fink 2.5 AGN classifier
#  16           0         213    6523             63  Fink 2.5 AGN classifier
#  17           0         214   38467             63  Fink 2.5 AGN classifier
#  18           0         221   15781             63  Fink 2.5 AGN classifier
#  19         221         111  101386             63  Fink 2.5 AGN classifier
#  20         221         112   21532             63  Fink 2.5 AGN classifier
#  21         221         113   93057             63  Fink 2.5 AGN classifier
#  22         221         114    2720             63  Fink 2.5 AGN classifier
#  23         221         115    2462             63  Fink 2.5 AGN classifier
#  24         221         122      48             63  Fink 2.5 AGN classifier
#  25         221         123     160             63  Fink 2.5 AGN classifier
#  26         221         124     100             63  Fink 2.5 AGN classifier
#  27         221         131    1948             63  Fink 2.5 AGN classifier
#  28         221         132     854             63  Fink 2.5 AGN classifier
#  29         221         133      74             63  Fink 2.5 AGN classifier
#  30         221         134     475             63  Fink 2.5 AGN classifier
#  31         221         135      28             63  Fink 2.5 AGN classifier
#  32         221         211     217             63  Fink 2.5 AGN classifier
#  33         221         212    7919             63  Fink 2.5 AGN classifier
#  34         221         213    1054             63  Fink 2.5 AGN classifier
#  35         221         214   17055             63  Fink 2.5 AGN classifier
#  36         221         221   14072             63  Fink 2.5 AGN classifier,
#  59:     pred_class  true_class      n  classifier_id  \
#  0            0         111  75359             59
#  1            0         112  15804             59
#  2            0         113  96632             59
#  3            0         114   2515             59
#  4            0         115   1816             59
#  ..         ...         ...    ...            ...
#  87          22         131    179             59
#  88          22         132    450             59
#  89          22         133      1             59
#  90          22         134     15             59
#  91          22         221   6476             59
#
#                                 classifier_name
#  0   Fink 2.5 CATS broad classifier version 1.0
#  1   Fink 2.5 CATS broad classifier version 1.0
#  2   Fink 2.5 CATS broad classifier version 1.0
#  3   Fink 2.5 CATS broad classifier version 1.0
#  4   Fink 2.5 CATS broad classifier version 1.0
#  ..                                         ...
#  87  Fink 2.5 CATS broad classifier version 1.0
#  88  Fink 2.5 CATS broad classifier version 1.0
#  89  Fink 2.5 CATS broad classifier version 1.0
#  90  Fink 2.5 CATS broad classifier version 1.0
#  91  Fink 2.5 CATS broad classifier version 1.0
#
#  [92 rows x 5 columns],
#  60:      pred_class  true_class      n  classifier_id  \
#  0             0         111  75359             60
#  1             0         112  15804             60
#  2             0         113  96632             60
#  3             0         114   2515             60
#  4             0         115   1816             60
#  ..          ...         ...    ...            ...
#  239         221         131    179             60
#  240         221         132    450             60
#  241         221         133      1             60
#  242         221         134     15             60
#  243         221         221   6476             60
#
#                                 classifier_name
#  0    Fink 2.5 CATS fine classifier version 1.0
#  1    Fink 2.5 CATS fine classifier version 1.0
#  2    Fink 2.5 CATS fine classifier version 1.0
#  3    Fink 2.5 CATS fine classifier version 1.0
#  4    Fink 2.5 CATS fine classifier version 1.0
#  ..                                         ...
#  239  Fink 2.5 CATS fine classifier version 1.0
#  240  Fink 2.5 CATS fine classifier version 1.0
#  241  Fink 2.5 CATS fine classifier version 1.0
#  242  Fink 2.5 CATS fine classifier version 1.0
#  243  Fink 2.5 CATS fine classifier version 1.0
#
#  [244 rows x 5 columns],
#  61:     pred_class  true_class       n  classifier_id              classifier_name
#  0            0         111  250955             61  Fink 2.5 EarlySN classifier
#  1            0         112   51100             61  Fink 2.5 EarlySN classifier
#  2            0         113  252857             61  Fink 2.5 EarlySN classifier
#  3            0         114    6925             61  Fink 2.5 EarlySN classifier
#  4            0         115    5351             61  Fink 2.5 EarlySN classifier
#  5            0         121       5             61  Fink 2.5 EarlySN classifier
#  6            0         122     192             61  Fink 2.5 EarlySN classifier
#  7            0         123     367             61  Fink 2.5 EarlySN classifier
#  8            0         124     494             61  Fink 2.5 EarlySN classifier
#  9            0         131    5771             61  Fink 2.5 EarlySN classifier
#  10           0         132    2311             61  Fink 2.5 EarlySN classifier
#  11           0         133     187             61  Fink 2.5 EarlySN classifier
#  12           0         134    1292             61  Fink 2.5 EarlySN classifier
#  13           0         135      84             61  Fink 2.5 EarlySN classifier
#  14           0         211     994             61  Fink 2.5 EarlySN classifier
#  15           0         212   40018             61  Fink 2.5 EarlySN classifier
#  16           0         213    7579             61  Fink 2.5 EarlySN classifier
#  17           0         214   62244             61  Fink 2.5 EarlySN classifier
#  18           0         221   34695             61  Fink 2.5 EarlySN classifier
#  19         111         111    7700             61  Fink 2.5 EarlySN classifier
#  20         111         112    1669             61  Fink 2.5 EarlySN classifier
#  21         111         113    7396             61  Fink 2.5 EarlySN classifier
#  22         111         114     267             61  Fink 2.5 EarlySN classifier
#  23         111         115     219             61  Fink 2.5 EarlySN classifier
#  24         111         123       1             61  Fink 2.5 EarlySN classifier
#  25         111         124       1             61  Fink 2.5 EarlySN classifier
#  26         111         131      52             61  Fink 2.5 EarlySN classifier
#  27         111         132      49             61  Fink 2.5 EarlySN classifier
#  28         111         133       2             61  Fink 2.5 EarlySN classifier
#  29         111         134      33             61  Fink 2.5 EarlySN classifier
#  30         111         214      51             61  Fink 2.5 EarlySN classifier
#  31         111         221     276             61  Fink 2.5 EarlySN classifier,
#  57:     pred_class  true_class       n  classifier_id  \
#  0            0         111  257255             57
#  1            0         112   52455             57
#  2            0         113  259522             57
#  3            0         114    7140             57
#  4            0         115    5523             57
#  5            0         121       5             57
#  6            0         122     192             57
#  7            0         123     368             57
#  8            0         124     495             57
#  9            0         131    5799             57
#  10           0         132    2353             57
#  11           0         133     188             57
#  12           0         134    1320             57
#  13           0         135      84             57
#  14           0         211     994             57
#  15           0         212   40018             57
#  16           0         213    7579             57
#  17           0         214   62295             57
#  18           0         221   34791             57
#  19         111         111    1400             57
#  20         111         112     314             57
#  21         111         113     731             57
#  22         111         114      52             57
#  23         111         115      47             57
#  24         111         131      24             57
#  25         111         132       7             57
#  26         111         133       1             57
#  27         111         134       5             57
#  28         111         221     180             57
#
#                           classifier_name
#  0   Fink 2.5 SuperNNova SN Ia classifier
#  1   Fink 2.5 SuperNNova SN Ia classifier
#  2   Fink 2.5 SuperNNova SN Ia classifier
#  3   Fink 2.5 SuperNNova SN Ia classifier
#  4   Fink 2.5 SuperNNova SN Ia classifier
#  5   Fink 2.5 SuperNNova SN Ia classifier
#  6   Fink 2.5 SuperNNova SN Ia classifier
#  7   Fink 2.5 SuperNNova SN Ia classifier
#  8   Fink 2.5 SuperNNova SN Ia classifier
#  9   Fink 2.5 SuperNNova SN Ia classifier
#  10  Fink 2.5 SuperNNova SN Ia classifier
#  11  Fink 2.5 SuperNNova SN Ia classifier
#  12  Fink 2.5 SuperNNova SN Ia classifier
#  13  Fink 2.5 SuperNNova SN Ia classifier
#  14  Fink 2.5 SuperNNova SN Ia classifier
#  15  Fink 2.5 SuperNNova SN Ia classifier
#  16  Fink 2.5 SuperNNova SN Ia classifier
#  17  Fink 2.5 SuperNNova SN Ia classifier
#  18  Fink 2.5 SuperNNova SN Ia classifier
#  19  Fink 2.5 SuperNNova SN Ia classifier
#  20  Fink 2.5 SuperNNova SN Ia classifier
#  21  Fink 2.5 SuperNNova SN Ia classifier
#  22  Fink 2.5 SuperNNova SN Ia classifier
#  23  Fink 2.5 SuperNNova SN Ia classifier
#  24  Fink 2.5 SuperNNova SN Ia classifier
#  25  Fink 2.5 SuperNNova SN Ia classifier
#  26  Fink 2.5 SuperNNova SN Ia classifier
#  27  Fink 2.5 SuperNNova SN Ia classifier
#  28  Fink 2.5 SuperNNova SN Ia classifier  ,
#  58:     pred_class  true_class      n  classifier_id  \
#  0            0         111  75359             58
#  1            0         112  15804             58
#  2            0         113  96632             58
#  3            0         114   2515             58
#  4            0         115   1816             58
#  ..         ...         ...    ...            ...
#  93          22         211     15             58
#  94          22         212   3400             58
#  95          22         213    513             58
#  96          22         214  13460             58
#  97          22         221  11054             58
#
#                                       classifier_name
#  0   Fink 2.5 SuperNNova broad classifier version 1.0
#  1   Fink 2.5 SuperNNova broad classifier version 1.0
#  2   Fink 2.5 SuperNNova broad classifier version 1.0
#  3   Fink 2.5 SuperNNova broad classifier version 1.0
#  4   Fink 2.5 SuperNNova broad classifier version 1.0
#  ..                                               ...
#  93  Fink 2.5 SuperNNova broad classifier version 1.0
#  94  Fink 2.5 SuperNNova broad classifier version 1.0
#  95  Fink 2.5 SuperNNova broad classifier version 1.0
#  96  Fink 2.5 SuperNNova broad classifier version 1.0
#  97  Fink 2.5 SuperNNova broad classifier version 1.0
#
#  [98 rows x 5 columns],
#  62:     pred_class  true_class       n  classifier_id  \
#  0            0         111  258655             62
#  1            0         112   52769             62
#  2            0         113  260253             62
#  3            0         114    7192             62
#  4            0         115    5570             62
#  5            0         121       5             62
#  6            0         122     192             62
#  7            0         123     368             62
#  8            0         124     495             62
#  9            0         131    5823             62
#  10           0         132    2360             62
#  11           0         133     189             62
#  12           0         134    1325             62
#  13           0         135      84             62
#  14           0         211     994             62
#  15           0         212   40018             62
#  16           0         213    7579             62
#  17           0         214   62295             62
#  18           0         221   34971             62
#
#                         classifier_name
#  0   Fink 2.5 T2 classifier version 1.0
#  1   Fink 2.5 T2 classifier version 1.0
#  2   Fink 2.5 T2 classifier version 1.0
#  3   Fink 2.5 T2 classifier version 1.0
#  4   Fink 2.5 T2 classifier version 1.0
#  5   Fink 2.5 T2 classifier version 1.0
#  6   Fink 2.5 T2 classifier version 1.0
#  7   Fink 2.5 T2 classifier version 1.0
#  8   Fink 2.5 T2 classifier version 1.0
#  9   Fink 2.5 T2 classifier version 1.0
#  10  Fink 2.5 T2 classifier version 1.0
#  11  Fink 2.5 T2 classifier version 1.0
#  12  Fink 2.5 T2 classifier version 1.0
#  13  Fink 2.5 T2 classifier version 1.0
#  14  Fink 2.5 T2 classifier version 1.0
#  15  Fink 2.5 T2 classifier version 1.0
#  16  Fink 2.5 T2 classifier version 1.0
#  17  Fink 2.5 T2 classifier version 1.0
#  18  Fink 2.5 T2 classifier version 1.0  }

# %%
client.plot_matrix( extension=None, show=True )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_50926/2649394423.py in <module>
# ----> 1 client.plot_matrix( extension=None, show=True )
#
# TypeError: plot_matrix() missing 1 required positional argument: 'matrix'
